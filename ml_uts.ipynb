# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READ DATA

# %%
dataset_train = pd.read_csv('dataset/train.csv')
dataset_test = pd.read_csv('dataset/test.csv')

# %%
df_train = dataset_train.copy()
df_test = dataset_test.copy()

# %%
df_train
# Out:
#           id  umur  indeks_masa_badan   jenis_makanan  penyakit_khusus  \
# 0      13777    51              29.45         jenis4                41
# 1      17804    18              22.22  jenis2 jenis5                36
# 2       2476    55              23.43  jenis3 jenis5                12
# 3      18360    30              21.88         jenis3                40
# 4      17530    35              17.25          jenis6               33
# ...      ...   ...                ...             ...              ...
# 19944   4821    26              21.37          jenis6               43
# 19945  21429    35              22.05         jenis5                28
# 19946  18601    22              21.44          jenis6               49
# 19947   2067    13              21.66  jenis2 jenis3                12
# 19948  13485    40              26.28         jenis5                 8
#
#       penyakit_keturunan lokasi_tinggal mengatur_pola_makan olahraga  \
# ...

# %%
df_test
# Out:
#          id  umur  indeks_masa_badan   jenis_makanan  penyakit_khusus  \
# 0      6774     5              18.03  jenis3 jenis4                26
# 1      8117    34              28.07          jenis6               46
# 2     24780    52              23.71         jenis4                34
# 3      8532    16              22.93         jenis2                26
# 4      9139     3              29.44         jenis3                31
# ...     ...   ...                ...             ...              ...
# 4983   9040    60              18.57          jenis6               15
# 4984  19022    64              29.18         jenis1                35
# 4985   2981    46              24.02         jenis2                25
# 4986  15814    38              29.51         jenis3                11
# 4987  19476    10              23.87  jenis2 jenis4                50
#
#      penyakit_keturunan lokasi_tinggal mengatur_pola_makan olahraga  \
# ...

# %%
df_train.columns
# Out:
# Index(['id', 'umur', 'indeks_masa_badan', 'jenis_makanan', 'penyakit_khusus',
#        'penyakit_keturunan', 'lokasi_tinggal', 'mengatur_pola_makan',
#        'olahraga', 'jam_tidur_teratur', 'merokok', 'minum_alkohol',
#        'mengkonsumsi_suplemen', 'memperhatikan_kesehatan_mental',
#        'bersosialisasi', 'jumlah_sakit_setahun_terakhir', 'sehat'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (19949, 17)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19949 entries, 0 to 19948
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19949 non-null  int64
#  1   umur                            19949 non-null  int64
#  2   indeks_masa_badan               19949 non-null  float64
#  3   jenis_makanan                   19949 non-null  object
#  4   penyakit_khusus                 19949 non-null  int64
#  5   penyakit_keturunan              19949 non-null  object
#  6   lokasi_tinggal                  19949 non-null  object
#  7   mengatur_pola_makan             19949 non-null  object
#  8   olahraga                        19949 non-null  object
#  9   jam_tidur_teratur               19949 non-null  object
#  10  merokok                         19949 non-null  object
#  11  minum_alkohol                   19949 non-null  object
# ...

# %%
df_train.describe()
# Out:
#                  id          umur  indeks_masa_badan  penyakit_khusus  \
# count  19949.000000  19949.000000       19949.000000     19949.000000
# mean   12453.449697     33.234047          23.466072        26.512557
# std     7203.749026     19.394246           3.767784        15.069903
# min        1.000000      0.000000          17.000000         1.000000
# 25%     6219.000000     17.000000          20.210000        13.000000
# 50%    12418.000000     33.000000          23.400000        26.000000
# 75%    18706.000000     50.000000          26.760000        40.000000
# max    24936.000000     66.000000          30.000000        52.000000
#
#        jumlah_sakit_setahun_terakhir
# count                   19949.000000
# mean                        1.757482
# std                         0.770115
# min                         1.000000
# 25%                         1.000000
# 50%                         2.000000
# 75%                         2.000000
# ...

# %%
df_test.describe()
# Out:
#                  id         umur  indeks_masa_badan  penyakit_khusus  \
# count   4988.000000  4988.000000        4988.000000      4988.000000
# mean   12526.192462    33.222133          23.432151        26.418404
# std     7179.579962    19.608735           3.768642        14.984825
# min        0.000000     0.000000          17.000000         1.000000
# 25%     6336.250000    16.000000          20.220000        13.000000
# 50%    12676.500000    34.000000          23.405000        26.000000
# 75%    18671.750000    51.000000          26.710000        39.000000
# max    24932.000000    66.000000          30.000000        52.000000
#
#        jumlah_sakit_setahun_terakhir       jenis1       jenis2       jenis3  \
# count                    4988.000000  4988.000000  4988.000000  4988.000000
# mean                        1.735365     0.174218     0.186247     0.179230
# std                         0.758440     0.379335     0.389345     0.383583
# ...

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.isnull().sum()
# Out:
# id                                0
# umur                              0
# indeks_masa_badan                 0
# jenis_makanan                     0
# penyakit_khusus                   0
# penyakit_keturunan                0
# lokasi_tinggal                    0
# mengatur_pola_makan               0
# olahraga                          0
# jam_tidur_teratur                 0
# merokok                           0
# minum_alkohol                     0
# mengkonsumsi_suplemen             0
# memperhatikan_kesehatan_mental    0
# bersosialisasi                    0
# jumlah_sakit_setahun_terakhir     0
# sehat                             0
# dtype: int64

# %%
df_train['id'].nunique()
# Out:
# 19949

# %%
df_train['umur'].value_counts()
# Out:
# umur
# 64    376
# 31    363
# 28    347
# 19    340
# 38    335
#      ...
# 10    260
# 27    260
# 66    260
# 20    258
# 45    257
# Name: count, Length: 67, dtype: int64

# %%
df_train['umur'].nunique()
# Out:
# 67

# %% [markdown]
# ## HIPOTESIS, DELETE YG UMUR 0

# %%
df_train.query('umur == 0')
# Out:
#           id  umur  indeks_masa_badan   jenis_makanan  penyakit_khusus  \
# 28      9949     0              28.60          jenis6               45
# 45      1720     0              23.05         jenis1                 7
# 51     21634     0              28.24          jenis6               49
# 128     7234     0              21.44  jenis1 jenis5                16
# 152    12664     0              20.00         jenis5                52
# ...      ...   ...                ...             ...              ...
# 19797  10507     0              28.19         jenis2                 3
# 19804  14724     0              28.24          jenis6               18
# 19866  18197     0              28.68         jenis2                16
# 19914  21643     0              23.65          jenis6                7
# 19934  15598     0              28.01          jenis6               19
#
#       penyakit_keturunan lokasi_tinggal mengatur_pola_makan olahraga  \
# ...

# %%
df_train['indeks_masa_badan'].value_counts()
# Out:
# indeks_masa_badan
# 20.21    40
# 17.23    38
# 19.28    37
# 19.05    36
# 24.23    35
#          ..
# 26.24     2
# 28.06     2
# 19.57     1
# 18.49     1
# 29.36     1
# Name: count, Length: 1301, dtype: int64

# %%
df_train['indeks_masa_badan'].nunique()
# Out:
# 1301

# %%
df_train['jenis_makanan'].value_counts()
# Out:
# jenis_makanan
# jenis6                                 7395
# jenis5                                 1696
# jenis2                                 1630
# jenis4                                 1625
# jenis3                                 1612
# jenis1                                 1607
# jenis2 jenis4                           370
# jenis1 jenis2                           369
# jenis4 jenis5                           363
# jenis1 jenis5                           354
# jenis2 jenis5                           346
# jenis1 jenis3                           344
# jenis3 jenis4                           344
# jenis2 jenis3                           342
# jenis1 jenis4                           341
# jenis3 jenis5                           338
# jenis1 jenis2 jenis5                     90
# jenis1 jenis2 jenis3                     88
# jenis1 jenis3 jenis4                     87
# jenis2 jenis3 jenis5                     80
# jenis1 jenis3 jenis5                     79
# ...

# %%
df_train['penyakit_khusus'].value_counts()
# Out:
# penyakit_khusus
# 49    434
# 17    419
# 1     419
# 19    416
# 36    410
# 48    409
# 40    407
# 6     404
# 12    400
# 8     399
# 25    399
# 11    398
# 41    396
# 24    396
# 30    395
# 5     392
# 23    391
# 7     391
# 29    391
# 43    389
# 39    388
# 34    387
# 52    387
# 4     386
# 44    386
# 20    383
# 22    381
# 42    381
# 50    380
# 51    379
# 18    379
# 46    379
# 31    378
# 33    378
# 3     377
# 35    375
# 21    374
# 27    373
# 28    372
# 45    370
# 10    369
# 9     368
# 47    365
# 32    365
# 16    364
# 13    363
# 2     363
# 15    356
# 26    354
# 38    348
# 37    344
# 14    342
# Name: count, dtype: int64

# %%
df_train['penyakit_keturunan'].value_counts()
# Out:
# penyakit_keturunan
# tidak ada    19949
# Name: count, dtype: int64

# %%
df_train['lokasi_tinggal'].value_counts()
# Out:
# lokasi_tinggal
# pedesaan     13882
# perkotaan     6067
# Name: count, dtype: int64

# %%
df_train['mengatur_pola_makan'].value_counts()
# Out:
# mengatur_pola_makan
# ya       17910
# tidak     2039
# Name: count, dtype: int64

# %%
df_train['olahraga'].value_counts()
# Out:
# olahraga
# tidak    17193
# ya        2756
# Name: count, dtype: int64

# %%
df_train['jam_tidur_teratur'].value_counts()
# Out:
# jam_tidur_teratur
# tidak    16216
# ya        3733
# Name: count, dtype: int64

# %%
df_train['merokok'].value_counts()
# Out:
# merokok
# tidak    11442
# ya        8507
# Name: count, dtype: int64

# %%
df_train['minum_alkohol'].value_counts()
# Out:
# minum_alkohol
# tidak    18225
# ya        1724
# Name: count, dtype: int64

# %%
df_train['mengkonsumsi_suplemen'].value_counts()
# Out:
# mengkonsumsi_suplemen
# tidak    18906
# ya        1043
# Name: count, dtype: int64

# %%
df_train['memperhatikan_kesehatan_mental'].value_counts()
# Out:
# memperhatikan_kesehatan_mental
# tidak    19949
# Name: count, dtype: int64

# %%
df_train['bersosialisasi'].value_counts()
# Out:
# bersosialisasi
# tidak    12055
# ya        7894
# Name: count, dtype: int64

# %%
df_train['jumlah_sakit_setahun_terakhir'].value_counts()
# Out:
# jumlah_sakit_setahun_terakhir
# 1.0    8476
# 2.0    8253
# 3.0    2829
# 4.0     364
# 5.0      27
# Name: count, dtype: int64

# %%
df_train['sehat'].value_counts()
# Out:
# sehat
# ya       12435
# tidak     7514
# Name: count, dtype: int64

# %% [markdown]
# ## Variabel

# %% [markdown]
# Variabel Numerical:
# 1. umur
# 2. indeks_masa_badan
# 3. penyakit_khusus
# 4. jumlah_sakit_setahun_terakhir
#
# Variabel Categorical:
# 1. jenis_makanan
# 2. penyakit_keturunan
# 3. lokasi_tinggal
# 4. mengatur_pola_makan
# 5. olahraga
# 6. jam_tidur_teratur
# 7. merokok
# 8. minum_alkohol
# 9. mengkonsumsi_suplemen
# 10. memperhatikan_kesehatan_mental
# 11. bersosialisasi
# 12. jumlah_sakit_setahun_terakhir
# 13. sehat

# %% [markdown]
# # Data Cleaning

# %%
df_clean_umur_train = df_train[df_train['umur']!=0]
df_clean_umur_test = df_test[df_test['umur']!=0]

# %% [markdown]
# # Normalisasi

# %%
df_train = dataset_train.copy()
df_test = dataset_test.copy()

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
# # Normalize numerical columns
# scaler = StandardScaler()
# numerical_features = ['umur', 'indeks_masa_badan', 'jumlah_sakit_setahun_terakhir']
# df_train[numerical_features] = scaler.fit_transform(df_train[numerical_features])
# df_test[numerical_features] = scaler.fit_transform(df_test[numerical_features])

# %%
# Membuat batasan untuk binning secara manual
bin_edges = [0, 10, 20, 30, 40, 50, 60, 70]

# Membuat label untuk binning
bin_labels = ['umur 0-10', 'umur 11-20', 'umur 21-30', 'umur 31-40', 'umur 41-50', 'umur 51-60', 'umur 61-70']

# Melakukan binning pada kolom 'umur' secara manual
df_train['umur'] = pd.cut(df_train['umur'], bins=bin_edges, labels=bin_labels, right=False)
df_test['umur'] = pd.cut(df_test['umur'], bins=bin_edges, labels=bin_labels, right=False)

# %%
df_train
# Out:
#           id        umur  indeks_masa_badan   jenis_makanan  penyakit_khusus  \
# 0      13777  umur 51-60              29.45         jenis4                41
# 1      17804  umur 11-20              22.22  jenis2 jenis5                36
# 2       2476  umur 51-60              23.43  jenis3 jenis5                12
# 3      18360  umur 31-40              21.88         jenis3                40
# 4      17530  umur 31-40              17.25          jenis6               33
# ...      ...         ...                ...             ...              ...
# 19944   4821  umur 21-30              21.37          jenis6               43
# 19945  21429  umur 31-40              22.05         jenis5                28
# 19946  18601  umur 21-30              21.44          jenis6               49
# 19947   2067  umur 11-20              21.66  jenis2 jenis3                12
# 19948  13485  umur 41-50              26.28         jenis5                 8
#
# ...

# %%
# Encode categorical columns
categorical_features = ['jenis_makanan', 'penyakit_khusus', 'penyakit_keturunan', 'lokasi_tinggal', 
                        'mengatur_pola_makan', 'olahraga', 'jam_tidur_teratur', 'merokok', 'minum_alkohol', 
                        'mengkonsumsi_suplemen', 'memperhatikan_kesehatan_mental', 'bersosialisasi']

# %%
encoder = OneHotEncoder(drop='first')

# Fit encoder on the training data and transform both training and test data
encoded_train_categorical = encoder.fit_transform(df_train[categorical_features]).toarray()
encoded_test_categorical = encoder.transform(df_test[categorical_features]).toarray()

# Create final datasets
final_train_data = pd.concat([df_train[numerical_features], pd.DataFrame(encoded_train_categorical)], axis=1)
final_test_data = pd.concat([df_test[numerical_features], pd.DataFrame(encoded_test_categorical)], axis=1)

# Add columns names to the encoded features (optional but useful for clarity)
encoded_feature_names = encoder.get_feature_names_out(categorical_features)
final_train_data.columns = list(df_train[numerical_features].columns) + list(encoded_feature_names)
final_test_data.columns = list(df_test[numerical_features].columns) + list(encoded_feature_names)

# Define target variable
target = df_train['sehat']

# %%
correlation_matrix = final_train_data.corr(numeric_only=True)
plt.figure(figsize=(20,12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
df_train
# Out:
#           id      umur  indeks_masa_badan   jenis_makanan  penyakit_khusus  \
# 0      13777  0.916065           1.588222         jenis4                41
# 1      17804 -0.785513          -0.330726  jenis2 jenis5                36
# 2       2476  1.122317          -0.009574  jenis3 jenis5                12
# 3      18360 -0.166757          -0.420967         jenis3                40
# 4      17530  0.091058          -1.649836          jenis6               33
# ...      ...       ...                ...             ...              ...
# 19944   4821 -0.373009          -0.556328          jenis6               43
# 19945  21429  0.091058          -0.375846         jenis5                28
# 19946  18601 -0.579261          -0.537749          jenis6               49
# 19947   2067 -1.043328          -0.479358  jenis2 jenis3                12
# 19948  13485  0.348873           0.746858         jenis5                 8
#
# ...

# %%
df_train.describe()
# Out:
#                  id          umur  indeks_masa_badan  penyakit_khusus  \
# count  19949.000000  1.994900e+04       1.994900e+04     19949.000000
# mean   12453.449697  1.124637e-16      -1.232382e-16        26.512557
# std     7203.749026  1.000025e+00       1.000025e+00        15.069903
# min        1.000000 -1.713646e+00      -1.716190e+00         1.000000
# 25%     6219.000000 -8.370758e-01      -8.642091e-01        13.000000
# 50%    12418.000000 -1.206815e-02      -1.753647e-02        26.000000
# 75%    18706.000000  8.645025e-01       8.742567e-01        40.000000
# max    24936.000000  1.689510e+00       1.734200e+00        52.000000
#
#        jumlah_sakit_setahun_terakhir
# count                   1.994900e+04
# mean                   -1.937617e-16
# std                     1.000025e+00
# min                    -9.836203e-01
# 25%                    -9.836203e-01
# 50%                     3.149199e-01
# 75%                     3.149199e-01
# ...

# %% [markdown]
# # Mapping

# %%
map_mengatur_pola_makan = {
    'ya': 1,
    'tidak': 0
}

df_train['mengatur_pola_makan'] = df_train['mengatur_pola_makan'].map(map_mengatur_pola_makan)
df_test['mengatur_pola_makan'] = df_test['mengatur_pola_makan'].map(map_mengatur_pola_makan)

# %%
map_olahraga = {
    'ya': 1,
    'tidak': 0
}

df_train['olahraga'] = df_train['olahraga'].map(map_olahraga)
df_test['olahraga'] = df_test['olahraga'].map(map_olahraga)

# %%
map_jam_tidur_teratur = {
    'ya': 1,
    'tidak': 0
}

df_train['jam_tidur_teratur'] = df_train['jam_tidur_teratur'].map(map_jam_tidur_teratur)
df_test['jam_tidur_teratur'] = df_test['jam_tidur_teratur'].map(map_jam_tidur_teratur)

# %%
map_merokok = {
    'ya': 1,
    'tidak': 0
}

df_train['merokok'] = df_train['merokok'].map(map_merokok)
df_test['merokok'] = df_test['merokok'].map(map_merokok)

# %%
map_minum_alkohol = {
    'ya': 1,
    'tidak': 0
}

df_train['minum_alkohol'] = df_train['minum_alkohol'].map(map_minum_alkohol)
df_test['minum_alkohol'] = df_test['minum_alkohol'].map(map_minum_alkohol)

# %%
map_mengkonsumsi_suplemen = {
    'ya': 1,
    'tidak': 0
}

df_train['mengkonsumsi_suplemen'] = df_train['mengkonsumsi_suplemen'].map(map_mengkonsumsi_suplemen)
df_test['mengkonsumsi_suplemen'] = df_test['mengkonsumsi_suplemen'].map(map_mengkonsumsi_suplemen)

# %%
map_bersosialisasi = {
    'ya': 1,
    'tidak': 0
}

df_train['bersosialisasi'] = df_train['bersosialisasi'].map(map_minum_alkohol)
df_test['bersosialisasi'] = df_test['bersosialisasi'].map(map_minum_alkohol)

# %%
map_sehat = {
    'ya': 0,
    'tidak': 1
}

df_train['sehat'] = df_train['sehat'].map(map_sehat)

# %%
correlation_matrix = df_train.corr(numeric_only=True)
plt.figure(figsize=(15,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
df_train.isna().sum()
# Out:
# id                                0
# umur                              0
# indeks_masa_badan                 0
# jenis_makanan                     0
# penyakit_khusus                   0
# penyakit_keturunan                0
# lokasi_tinggal                    0
# mengatur_pola_makan               0
# olahraga                          0
# jam_tidur_teratur                 0
# merokok                           0
# minum_alkohol                     0
# mengkonsumsi_suplemen             0
# memperhatikan_kesehatan_mental    0
# bersosialisasi                    0
# jumlah_sakit_setahun_terakhir     0
# sehat                             0
# dtype: int64

# %% [markdown]
# # Distribusi Data

# %% [markdown]
# perlu gak?

# %%
sns.histplot(data=df_train, x='umur')
# Out:
# <Axes: xlabel='umur', ylabel='Count'>

# %% [markdown]
# # Exploratory Data Analysis

# %%
df_sampled = df_train.sample(frac=0.1, random_state=1)

# %% [markdown]
# ## Univariate Analysis

# %%
sns.boxplot(data=df_train, x='umur')
# Out:
# <Axes: xlabel='umur'>

# %%
sns.boxplot(data=df_train, x='indeks_masa_badan')
# Out:
# <Axes: xlabel='indeks_masa_badan'>

# %%
sns.boxplot(data=df_train, x='penyakit_khusus')
# Out:
# <Axes: xlabel='penyakit_khusus'>

# %%
sns.boxplot(data=df_train, x='jumlah_sakit_setahun_terakhir')
# Out:
# <Axes: xlabel='jumlah_sakit_setahun_terakhir'>

# %%
sns.countplot(data=df_train, y='jenis_makanan')
# Out:
# <Axes: xlabel='count', ylabel='jenis_makanan'>

# %% [markdown]
# ## Multivariate Analysis

# %%
correlation_matrix = df_train.corr(numeric_only=True)
# plt.figure(figsize=(20,12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
# Create sample data
data = {
    'id': [1, 2, 3],
    'values': [np.array([10, 20, 30]), np.array([40, 50, 60]), np.array([70, 80, 90])]
}

# Create DataFrame
df = pd.DataFrame(data)

# Accessing the array in the first row
print(df.loc[0, 'values'])

# Adding a new array to the DataFrame
df.loc[3] = [4, np.array([100, 110, 120])]

df
# Out:
# [10 20 30]
#    id           values
# 0   1     [10, 20, 30]
# 1   2     [40, 50, 60]
# 2   3     [70, 80, 90]
# 3   4  [100, 110, 120]

# %% [markdown]
# # Predict NO CLEAN

# %%
df_train = dataset_train.copy()
df_test = dataset_test.copy()

# %%
# 0.830
# CatBoost Accuracy: 0.8431077694235589
# drop aja karena di public akurasi kaggle model yg ini lebih gede akurasinya walaupun disini lebih kecil ketimbang di tidak di drop
# tidak memberikan perubahan akurasi ketika kolom-kolom ini di drop ataupun dipakai
df_train = df_train.drop(['penyakit_keturunan','memperhatikan_kesehatan_mental'], axis=1)
df_test = df_test.drop(['penyakit_keturunan','memperhatikan_kesehatan_mental'], axis=1)

# # CatBoost Accuracy: 0.845279866332498
# df_train = df_train.drop(['penyakit_keturunan','memperhatikan_kesehatan_mental'], axis=1)
# df_test = df_test.drop(['penyakit_keturunan','memperhatikan_kesehatan_mental'], axis=1)


# # kode di atas dikomen hasil akurasi catboost lebih besar
# # CatBoost Accuracy: 0.845279866332498

# %%
# # 0.794
# df_train = df_train[['id','merokok','penyakit_khusus','jenis_makanan','indeks_masa_badan','umur','sehat']]
# df_test = df_test[['id','merokok','penyakit_khusus','jenis_makanan','indeks_masa_badan','umur']]

# %%
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import SMOTE

from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report

# %%
# df_test['penyakit_khusus'] = 'id ' + df_test['penyakit_khusus'].astype(str)
# df_train['penyakit_khusus'] = 'id ' + df_train['penyakit_khusus'].astype(str)

# Split the strings in the 'jenis' column by space and create dummy variables
jenis_dummies1 = df_test['jenis_makanan'].str.get_dummies(sep=' ')
jenis_dummies2 = df_train['jenis_makanan'].str.get_dummies(sep=' ')

# Concatenate the dummy variables with the original DataFrame
df_test = pd.concat([df_test, jenis_dummies1], axis=1)
df_train = pd.concat([df_train, jenis_dummies2], axis=1)

# Drop the original 'jenis' column if needed
df_test = df_test.drop('jenis_makanan', axis=1)
df_train = df_train.drop('jenis_makanan', axis=1)

# %%
df_test = pd.get_dummies(df_test)
target = df_train['sehat']
df_train.drop(['sehat'], axis=1, inplace=True)
df_train = pd.get_dummies(df_train)

# %%
df_test = df_test.reindex(columns=df_train.columns, fill_value=0)
df_train = df_train.reindex(columns=df_test.columns, fill_value=0)

# %%
label_encoder = LabelEncoder()

# Memisahkan fitur dan label
X = df_train.drop(columns=['id'])  # Menghilangkan kolom 'sehat' dan 'id' dari fitur
y = label_encoder.fit_transform(target)

# Melakukan one-hot encoding pada fitur-fitur kategorikal (jika diperlukan)
X_encoded = pd.get_dummies(X)  # Gunakan pd.get_dummies() atau OneHotEncoder jika perlu

# Membagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.3, random_state=42)

# smote = SMOTE(random_state=42)
# X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
df_train.columns
# Out:
# Index(['id', 'umur', 'indeks_masa_badan', 'penyakit_khusus',
#        'jumlah_sakit_setahun_terakhir', 'jenis1', 'jenis2', 'jenis3', 'jenis4',
#        'jenis5', 'jenis6', 'lokasi_tinggal_pedesaan',
#        'lokasi_tinggal_perkotaan', 'mengatur_pola_makan_tidak',
#        'mengatur_pola_makan_ya', 'olahraga_tidak', 'olahraga_ya',
#        'jam_tidur_teratur_tidak', 'jam_tidur_teratur_ya', 'merokok_tidak',
#        'merokok_ya', 'minum_alkohol_tidak', 'minum_alkohol_ya',
#        'mengkonsumsi_suplemen_tidak', 'mengkonsumsi_suplemen_ya',
#        'bersosialisasi_tidak', 'bersosialisasi_ya'],
#       dtype='object')

# %%
# def train_model(model, X_train, y_train, X_test, y_test):
#     # Melatih model
#     model.fit(X_train, y_train)
    
#     # Memprediksi pada data latih dan data uji
#     train_pred = model.predict(X_train)
#     test_pred = model.predict(X_test)

#     # Menghitung akurasi
#     train_accuracy = accuracy_score(y_train, train_pred)
#     test_accuracy = accuracy_score(y_test, test_pred)

#     print("Accuracy on training set: {:.3f}".format(train_accuracy))
#     print("Accuracy on test set: {:.3f}".format(test_accuracy))



# Fungsi untuk melatih dan mengevaluasi model
def train_model(model, name):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{name} Accuracy: {accuracy}")
    print(f"Classification Report {name}:")
    print(classification_report(y_test, y_pred))



# def train_model(model, name):
#     model.fit(X_train_resampled, y_train_resampled)  # Menggunakan data latih yang telah di-resample
#     y_pred = model.predict(X_test)
#     accuracy = accuracy_score(y_test, y_pred)
#     print(f"{name} Accuracy: {accuracy}")
#     print(f"Classification Report {name}:")
#     print(classification_report(y_test, y_pred))

# %%
# Model Prediksi dengan random_state diatur
models_to_train = {
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "SVM": SVC(),  # SVC tidak memiliki random_state, tetapi bisa ditentukan dalam parameter lain seperti `SVC(random_state=42)`
    "KNN": KNeighborsClassifier(),  # KNN tidak memiliki random_state
    "Logistic Regression": LogisticRegression(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Naive Bayes": GaussianNB(),  # GaussianNB tidak memiliki random_state
    "XGBoost": XGBClassifier(random_state=42),
    "CatBoost": CatBoostClassifier(random_state=42, verbose=0),  # verbose=0 untuk mengurangi output training
    "LightGBM": LGBMClassifier(random_state=42, verbose=0) # verbose=0 untuk mengurangi output training
}

for name, model in models_to_train.items():
    print(f"\nTraining {name}...")
    train_model(model, name)
# Out:
# Training Gradient Boosting...
# Gradient Boosting Accuracy: 0.8295739348370927
# Classification Report Gradient Boosting:
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76      2247
#            1       0.85      0.89      0.87      3738
#
#     accuracy                           0.83      5985
#    macro avg       0.82      0.81      0.81      5985
# weighted avg       0.83      0.83      0.83      5985
#
#
# Training Random Forest...
# Random Forest Accuracy: 0.8073517126148705
# Classification Report Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.76      0.70      0.73      2247
#            1       0.83      0.87      0.85      3738
#
#     accuracy                           0.81      5985
#    macro avg       0.80      0.79      0.79      5985
# weighted avg       0.81      0.81      0.81      5985
#
#
# Training Decision Tree...
# Decision Tree Accuracy: 0.7692564745196324
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import VotingClassifier

# %%
# Identifikasi kolom numerik dan kolom kategori
numeric_features = ['umur', 'indeks_masa_badan', 'jumlah_sakit_setahun_terakhir']
categorical_features = [col for col in X_train.columns if col not in numeric_features]

# %%
# Buat transformer untuk preprocessing numerik dan kategori
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent'))
    # Karena one hot encoding dan labelEncoder sudah dilakukan maka tidak perlu encoder lagi
])

# %%
# Kombinasikan transformer ke dalam satu ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ],
    remainder='passthrough'  # Kolom yang sudah di-encode akan dilewatkan tanpa perubahan
)

# %%
# Definisikan pipeline dengan preprocessor dan CatBoostClassifier
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
])

# %%
CatBoost_model = CatBoostClassifier(random_state=42, verbose=0)
XGB_model = XGBClassifier(random_state=42)
LGBM_model = LGBMClassifier(random_state=42, verbose=0)

# %%
param_grid_cat ={
    'iterations': [100, 500, 1000],
    'depth': [4, 6, 8, 10],
    'learning_rate': [0.01, 0.05, 0.1, 0.5]
}

# %%
cat_cv = GridSearchCV(CatBoost_model, param_grid_cat, cv=3, scoring='accuracy', n_jobs=-1)

# %%
cat_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostClassifier object at 0x0000014E9D8EEC90>,
#              n_jobs=-1,
#              param_grid={'depth': [4, 6, 8, 10], 'iterations': [100, 500, 1000],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.5]},
#              scoring='accuracy')

# %%
# Mendapatkan parameter terbaik dan model terbaik
best_params_cat = cat_cv.best_params_
best_cat_model = cat_cv.best_estimator_

# %%
# Memprediksi data uji
y_pred_cat = best_cat_model.predict(X_test)

# %%
# Menghitung dan mencetak akurasi
accuracy_cat = accuracy_score(y_test, y_pred_cat)
print(f"Best Parameters CatBoost: {best_params_cat}")
print(f"CatBoost Accuracy: {accuracy_cat}")
print(f"Classification Report CatBoost:\n{classification_report(y_test, y_pred_cat)}")
# Out:
# Best Parameters CatBoost: {'depth': 4, 'iterations': 500, 'learning_rate': 0.05}
# CatBoost Accuracy: 0.8416040100250627
# Classification Report CatBoost:
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.78      2247
#            1       0.86      0.89      0.88      3738
#
#     accuracy                           0.84      5985
#    macro avg       0.83      0.82      0.83      5985
# weighted avg       0.84      0.84      0.84      5985

# %%
param_grid_XGB = {
    'learning_rate': [0.05, 0.1, 0.2],
    'n_estimators': [300],
    'max_depth': [3],
    'min_child_weight': [1,2,3],
    'gamma': [0, 0.1, 0.2],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
}

# %%
xgb_cv = GridSearchCV(XGB_model, param_grid_XGB, cv=3, scoring='accuracy', n_jobs=-1)

# %%
xgb_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
# ...

# %%
# Mendapatkan parameter terbaik dan model terbaik
best_params_xgb = xgb_cv.best_params_
best_xgb_model = xgb_cv.best_estimator_

# %%
# Memprediksi data uji
y_pred_xgb = best_xgb_model.predict(X_test)

# %%
# Menghitung dan mencetak akurasi
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
print(f"Best Parameters XGB: {best_params_xgb}")
print(f"XGBoost Accuracy: {accuracy_xgb}")
print(f"Classification Report XGB:\n{classification_report(y_test, y_pred_xgb)}")
# Out:
# Best Parameters XGB: {'colsample_bytree': 0.8, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 300, 'subsample': 0.8}
# XGBoost Accuracy: 0.8379281537176274
# Classification Report XGB:
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78      2247
#            1       0.86      0.89      0.87      3738
#
#     accuracy                           0.84      5985
#    macro avg       0.83      0.82      0.83      5985
# weighted avg       0.84      0.84      0.84      5985

# %%
param_grid_lgbm = {
    'boosting_type': ['gbdt', 'dart'],
    'num_leaves': [20, 30, 40],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 300]
}

# %%
lgbm_cv = GridSearchCV(LGBM_model, param_grid_lgbm, cv=3, scoring='accuracy', n_jobs=-1)

# %%
lgbm_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=LGBMClassifier(random_state=42, verbose=0),
#              n_jobs=-1,
#              param_grid={'boosting_type': ['gbdt', 'dart'],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'n_estimators': [100, 200, 300],
#                          'num_leaves': [20, 30, 40]},
#              scoring='accuracy')

# %%
# Mendapatkan parameter terbaik dan model terbaik
best_params_lgbm = lgbm_cv.best_params_
best_lgbm_model = lgbm_cv.best_estimator_

# %%
# Memprediksi data uji
y_pred_lgbm = best_lgbm_model.predict(X_test)

# %%
# Menghitung dan mencetak akurasi
accuracy_lgbm = accuracy_score(y_test, y_pred_lgbm)
print(f"Best Parameters LGBM: {best_params_lgbm}")
print(f"LGBM Accuracy: {accuracy_lgbm}")
print(f"Classification Report LGBM:\n{classification_report(y_test, y_pred_lgbm)}")
# Out:
# Best Parameters LGBM: {'boosting_type': 'gbdt', 'learning_rate': 0.05, 'n_estimators': 300, 'num_leaves': 20}
# LGBM Accuracy: 0.8426065162907268
# Classification Report LGBM:
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79      2247
#            1       0.87      0.88      0.88      3738
#
#     accuracy                           0.84      5985
#    macro avg       0.83      0.83      0.83      5985
# weighted avg       0.84      0.84      0.84      5985

# %%
# Menggabungkan model terbaik dari pencarian grid untuk CatBoost, XGBoost, dan LightGBM
estimators = [
    ('catboost', cat_cv.best_estimator_),
    ('xgboost', xgb_cv.best_estimator_),
    ('lightgbm', lgbm_cv.best_estimator_)
]

# Membuat objek VotingClassifier
vc = VotingClassifier(estimators, voting='soft')  # Soft voting mengambil rata-rata probabilitas kelas dari semua model

# %%
# Melatih model VotingClassifier
vc.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('catboost',
#                               <catboost.core.CatBoostClassifier object at 0x0000014E9D8DBC10>),
#                              ('xgboost',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=0.2,
#                                             gr...
#                                             max_cat_threshold=None,
# ...

# %%
# Memperkirakan label pada data uji
y_pred_vc = vc.predict(X_test)

# %%
# Menghitung dan mencetak akurasi
accuracy_vc = accuracy_score(y_test, y_pred_vc)
print(f"CatBoost Accuracy: {accuracy_vc}")
print(f"Classification Report Voting Classifier:\n{classification_report(y_test, y_pred_vc)}")
# Out:
# CatBoost Accuracy: 0.8402673350041772
# Classification Report Voting Classifier:
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78      2247
#            1       0.86      0.89      0.87      3738
#
#     accuracy                           0.84      5985
#    macro avg       0.83      0.82      0.83      5985
# weighted avg       0.84      0.84      0.84      5985

# %%
# Penyetelan Hyperparameter dengan GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.05, 0.1, 0.2]
}
catboost_model = CatBoostClassifier()
grid_search = GridSearchCV(catboost_model, param_grid, cv=5, scoring='accuracy', n_jobs=1)
grid_search.fit(X_train, y_train)

# Model Prediksi
best_catboost_model = grid_search.best_estimator_
best_catboost_model.fit(X_train, y_train)
y_pred = best_catboost_model.predict(X_test)

# Evaluasi Model
print("CatBoost Classifier Accuracy after Improvement:")
print(accuracy_score(y_test, y_pred))
print("Classification Report CatBoost Classifier after Improvement:")
print(classification_report(y_test, y_pred))
# Out:
# 0:	learn: 0.6694204	total: 8.57ms	remaining: 420ms
# 1:	learn: 0.6485478	total: 16.9ms	remaining: 406ms
# 2:	learn: 0.6295661	total: 25.9ms	remaining: 406ms
# 3:	learn: 0.6123970	total: 34.3ms	remaining: 394ms
# 4:	learn: 0.5934779	total: 42.3ms	remaining: 381ms
# 5:	learn: 0.5765392	total: 51.2ms	remaining: 375ms
# 6:	learn: 0.5649826	total: 59.8ms	remaining: 367ms
# 7:	learn: 0.5524739	total: 68.4ms	remaining: 359ms
# 8:	learn: 0.5434796	total: 77.6ms	remaining: 354ms
# 9:	learn: 0.5332072	total: 86ms	remaining: 344ms
# 10:	learn: 0.5254340	total: 95.3ms	remaining: 338ms
# 11:	learn: 0.5192839	total: 105ms	remaining: 331ms
# 12:	learn: 0.5120620	total: 114ms	remaining: 323ms
# 13:	learn: 0.5056290	total: 123ms	remaining: 316ms
# 14:	learn: 0.4988620	total: 132ms	remaining: 309ms
# 15:	learn: 0.4932395	total: 142ms	remaining: 301ms
# 16:	learn: 0.4888820	total: 151ms	remaining: 294ms
# 17:	learn: 0.4835947	total: 161ms	remaining: 287ms
# ...

# %%
from sklearn.model_selection import StratifiedKFold

# Penyetelan Hyperparameter dengan GridSearchCV dan Stratified K-Fold Cross Validation
param_grid = {
    'n_estimators': [100, 150, 200],
    'learning_rate': [0.05, 0.1, 0.2],
    'depth': [3, 5, 7]  # Hyperparameter tambahan untuk CatBoostClassifier
}
catboost_model = CatBoostClassifier()
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(catboost_model, param_grid, cv=stratified_kfold, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Model Prediksi
best_catboost_model = grid_search.best_estimator_
y_pred = best_catboost_model.predict(X_test)

# Evaluasi Model
print("CatBoost Classifier Accuracy after Improvement:")
print(accuracy_score(y_test, y_pred))
print("Classification Report CatBoost Classifier after Improvement:")
print(classification_report(y_test, y_pred))
# Out:
# 0:	learn: 0.6750273	total: 6.07ms	remaining: 601ms
# 1:	learn: 0.6582198	total: 12.6ms	remaining: 617ms
# 2:	learn: 0.6437600	total: 19.4ms	remaining: 627ms
# 3:	learn: 0.6302044	total: 25.2ms	remaining: 604ms
# 4:	learn: 0.6185285	total: 31.1ms	remaining: 592ms
# 5:	learn: 0.6098514	total: 37.8ms	remaining: 592ms
# 6:	learn: 0.6005536	total: 43.8ms	remaining: 582ms
# 7:	learn: 0.5922836	total: 52.8ms	remaining: 608ms
# 8:	learn: 0.5846697	total: 60.6ms	remaining: 612ms
# 9:	learn: 0.5795201	total: 68ms	remaining: 612ms
# 10:	learn: 0.5733832	total: 75ms	remaining: 607ms
# 11:	learn: 0.5672873	total: 82.6ms	remaining: 606ms
# 12:	learn: 0.5622612	total: 88.4ms	remaining: 592ms
# 13:	learn: 0.5582796	total: 94.3ms	remaining: 579ms
# 14:	learn: 0.5539232	total: 101ms	remaining: 571ms
# 15:	learn: 0.5494004	total: 107ms	remaining: 561ms
# 16:	learn: 0.5451612	total: 113ms	remaining: 550ms
# 17:	learn: 0.5401051	total: 117ms	remaining: 534ms
# ...

# %%
# Penanganan Ketidakseimbangan Kelas dengan SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Pemrosesan Lebih Lanjut dengan Penskalaan Fitur
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)

# Penyetelan Hyperparameter dengan GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.05, 0.1, 0.2]
}
lgbm_model = LGBMClassifier()
grid_search = lgbm_model(catboost_model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train_scaled, y_train_resampled)

# Model Prediksi
best_catboost_model = grid_search.best_estimator_
best_catboost_model.fit(X_train_scaled, y_train_resampled)
y_pred = best_catboost_model.predict(X_test_scaled)

# Evaluasi Model
print("CatBoost Classifier Accuracy after Improvement:")
print(accuracy_score(y_test, y_pred))
print("Classification Report CatBoost Classifier after Improvement:")
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 16
#      11 param_grid = {
#      12     'n_estimators': [50, 100, 150],
#      13     'learning_rate': [0.05, 0.1, 0.2]
#      14 }
#      15 lgbm_model = LGBMClassifier()
# ---> 16 grid_search = lgbm_model(catboost_model, param_grid, cv=5, scoring='accuracy')
#      17 grid_search.fit(X_train_scaled, y_train_resampled)
#      19 # Model Prediksi
#
# TypeError: 'LGBMClassifier' object is not callable

# %%
# # Membuat model Gradient Boosting
# gradient_boosting = GradientBoostingClassifier(random_state=0)
# print("Gradient Boosting Classifier:")
# train_model(gradient_boosting, X_train, y_train, X_test, y_test)

# # Membuat model Decision Tree
# decision_tree = DecisionTreeClassifier(random_state=0)
# print("\nDecision Tree Classifier:")
# train_model(decision_tree, X_train, y_train, X_test, y_test)

# # Membuat model Random Forest
# random_forest = RandomForestClassifier(random_state=0)
# print("\nRandom Forest Classifier:")
# train_model(random_forest, X_train, y_train, X_test, y_test)

# # Membuat model SVM
# svm_model = SVC()
# print("\nSupport Vector Machine Classifier:")
# train_model(svm_model, X_train, y_train, X_test, y_test)

# # Membuat model KNN
# knn_model = KNeighborsClassifier()
# print("\nKNeighbors Classifier:")
# train_model(knn_model, X_train, y_train, X_test, y_test)

# # Membuat model Logistic Regression
# lr_model = LogisticRegression()
# print("\nLogistic Regression Classifier:")
# train_model(lr_model, X_train, y_train, X_test, y_test)

# # Membuat model AdaBoost
# adaboost_model = AdaBoostClassifier()
# print("\nAdaBoost Classifier:")
# train_model(adaboost_model, X_train, y_train, X_test, y_test)

# # Membuat model XGBoost
# XGBoost_model = XGBClassifier()
# print("\nXGBoost Classifier:")
# train_model(XGBoost_model, X_train, y_train, X_test, y_test)

# # Membuat model CatBoost
# CatBoost_model = CatBoostClassifier()
# print("\nCatBoost Classifier:")
# train_model(CatBoost_model, X_train, y_train, X_test, y_test)

# # Membuat model LightGBM
# LightGBM_model = LGBMClassifier()
# print("\nLightGBM Classifier:")
# train_model(LightGBM_model, X_train, y_train, X_test, y_test)

# %%
# df_test = df_test.reindex(columns=df_train.columns, fill_value=0)
# df_train = df_train.reindex(columns=df_test.columns, fill_value=0)

# %%
# df_test_predictions = best_catboost_model.predict(df_test)

# %%
CatBoost_model = CatBoostClassifier()

# %%
CatBoost_model.fit(X_train, y_train)
# Out:
# Learning rate set to 0.031758
# 0:	learn: 0.6772285	total: 13.4ms	remaining: 13.3s
# 1:	learn: 0.6639737	total: 26.9ms	remaining: 13.4s
# 2:	learn: 0.6512758	total: 38.6ms	remaining: 12.8s
# 3:	learn: 0.6386519	total: 50.9ms	remaining: 12.7s
# 4:	learn: 0.6237729	total: 64ms	remaining: 12.7s
# 5:	learn: 0.6123148	total: 75.9ms	remaining: 12.6s
# 6:	learn: 0.6024493	total: 88ms	remaining: 12.5s
# 7:	learn: 0.5925979	total: 101ms	remaining: 12.5s
# 8:	learn: 0.5818331	total: 114ms	remaining: 12.5s
# 9:	learn: 0.5734796	total: 127ms	remaining: 12.5s
# 10:	learn: 0.5663619	total: 140ms	remaining: 12.6s
# 11:	learn: 0.5588924	total: 154ms	remaining: 12.7s
# 12:	learn: 0.5523902	total: 168ms	remaining: 12.7s
# 13:	learn: 0.5463785	total: 181ms	remaining: 12.7s
# 14:	learn: 0.5392643	total: 193ms	remaining: 12.7s
# 15:	learn: 0.5347400	total: 207ms	remaining: 12.8s
# 16:	learn: 0.5298167	total: 233ms	remaining: 13.5s
# 17:	learn: 0.5247101	total: 246ms	remaining: 13.4s
# ...

# %%
simpanid = df_test['id']
df_test.drop('id', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 simpanid = df_test['id']
# ...

# %%
df_test = df_test.drop(columns=['sehat'])
train_pred_df = vc.predict(df_test)

# %%
# train_pred_df = CatBoost_model.predict(df_test)

# %%
df_test['sehat'] = train_pred_df
df_test['id'] = simpanid
df_subset = df_test[['id', 'sehat']]
df_subset['sehat'] = df_subset['sehat'].map({1: 'ya', 0: 'tidak'})
df_subset
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22160\3697335397.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['sehat'] = df_subset['sehat'].map({1: 'ya', 0: 'tidak'})
#          id  sehat
# 0      6774  tidak
# 1      8117  tidak
# 2     24780  tidak
# 3      8532     ya
# 4      9139  tidak
# ...     ...    ...
# 4983   9040  tidak
# 4984  19022     ya
# 4985   2981     ya
# 4986  15814  tidak
# 4987  19476     ya
#
# [4988 rows x 2 columns]

# %%
df_subset.to_csv("hasilml_p9.csv", index=False)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# Memisahkan fitur dan label
X = df_train.drop(columns=['id'])  # Menghilangkan kolom 'sehat' dan 'id' dari fitur
y = simpan  # Menggunakan 'sehat' sebagai label

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode labels (y)
y_encoded = label_encoder.fit_transform(y)

# Melakukan one-hot encoding pada fitur-fitur kategorikal
X_encoded = pd.get_dummies(X)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Membagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)

# Inisialisasi model ANN
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Kompilasi model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Melatih model
history = model.fit(X_train, y_train, epochs=10, batch_size=64, validation_split=0.2)

# Evaluasi model pada data uji
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# C:\Users\Lenovo\scoop\apps\python311\current\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6391 - loss: 0.6434 - val_accuracy: 0.7354 - val_loss: 0.5403
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7086 - loss: 0.5689 - val_accuracy: 0.7454 - val_loss: 0.5221
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7313 - loss: 0.5392 - val_accuracy: 0.7512 - val_loss: 0.5169
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7265 - loss: 0.5403 - val_accuracy: 0.7497 - val_loss: 0.5119
# Epoch 5/10
# ...

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# Memisahkan fitur dan label
X = df_train.drop(columns=['sehat', 'id'])  # Menghilangkan kolom 'sehat' dan 'id' dari fitur
y = df_train['sehat']  # Menggunakan 'sehat' sebagai label

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode labels (y)
y_encoded = label_encoder.fit_transform(y)

# Melakukan one-hot encoding pada fitur-fitur kategorikal
X_encoded = pd.get_dummies(X)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Membagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Inisialisasi model Naive Bayes
naive_bayes = GaussianNB()

# Melatih model
naive_bayes.fit(X_train, y_train)

# Memprediksi pada data uji
y_pred = naive_bayes.predict(X_test)

# Menghitung akurasi
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# %% [markdown]
# # PREDICT DF CLEAN UMUR

# %%
df_train = dataset_train.copy()
df_test = dataset_test.copy()

# %%
df_clean_umur_train = df_train[df_train['umur']!=0]
df_clean_umur_test = df_test[df_test['umur']!=0]

# %%
# df_test['penyakit_khusus'] = 'id ' + df_test['penyakit_khusus'].astype(str)
# df_train['penyakit_khusus'] = 'id ' + df_train['penyakit_khusus'].astype(str)

# Split the strings in the 'jenis' column by space and create dummy variables
jenis_dummies1 = df_clean_umur_test['jenis_makanan'].str.get_dummies(sep=' ')
jenis_dummies2 = df_clean_umur_train['jenis_makanan'].str.get_dummies(sep=' ')

# Concatenate the dummy variables with the original DataFrame
df_clean_umur_test = pd.concat([df_clean_umur_test, jenis_dummies1], axis=1)
df_clean_umur_train = pd.concat([df_clean_umur_train, jenis_dummies2], axis=1)

# Drop the original 'jenis' column if needed
df_clean_umur_test = df_clean_umur_test.drop('jenis_makanan', axis=1)
df_clean_umur_train = df_clean_umur_train.drop('jenis_makanan', axis=1)

# %%
df_clean_umur_test = pd.get_dummies(df_clean_umur_test)
simpan = df_clean_umur_train['sehat']
df_clean_umur_train.drop('sehat', axis=1, inplace=True)
df_clean_umur_train = pd.get_dummies(df_clean_umur_train)

# %%
df_clean_umur_test = df_clean_umur_test.reindex(columns=df_clean_umur_train.columns, fill_value=0)
df_clean_umur_train = df_clean_umur_train.reindex(columns=df_clean_umur_test.columns, fill_value=0)

# %%
# Memisahkan fitur dan label
X = df_clean_umur_train.drop(columns=['id'])  # Menghilangkan kolom 'sehat' dan 'id' dari fitur

# Melakukan one-hot encoding pada fitur-fitur kategorikal
X_encoded = pd.get_dummies(X)

# Membagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X_encoded, simpan, test_size=0.3 , random_state=42)  # tambahkan random_state

# %%
# Definisikan fungsi untuk melatih dan mengevaluasi model
def train_model(model, X_train, y_train, X_test, y_test):
    # Melatih model
    model.fit(X_train, y_train)
    
    # Memprediksi pada data latih dan data uji
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    # Menghitung akurasi
    train_accuracy = accuracy_score(y_train, train_pred)
    test_accuracy = accuracy_score(y_test, test_pred)

    print("Accuracy on training set: {:.3f}".format(train_accuracy))
    print("Accuracy on test set: {:.3f}".format(test_accuracy))

# %%
# Membuat model Gradient Boosting
gradient_boosting = GradientBoostingClassifier(random_state=0)
print("Gradient Boosting Classifier:")
train_model(gradient_boosting, X_train, y_train, X_test, y_test)

# Membuat model Decision Tree
decision_tree = DecisionTreeClassifier(random_state=0)
print("\nDecision Tree Classifier:")
train_model(decision_tree, X_train, y_train, X_test, y_test)

# Membuat model Random Forest
random_forest = RandomForestClassifier(random_state=0)
print("\nRandom Forest Classifier:")
train_model(random_forest, X_train, y_train, X_test, y_test)

# Membuat model SVM
svm_model = SVC()
print("\nSupport Vector Machine Classifier:")
train_model(svm_model, X_train, y_train, X_test, y_test)

# Membuat model KNN
knn_model = KNeighborsClassifier()
print("\nKNeighbors Classifier:")
train_model(knn_model, X_train, y_train, X_test, y_test)

# Membuat model Logistic Regression
lr_model = LogisticRegression()
print("\nLogistic Regression Classifier:")
train_model(lr_model, X_train, y_train, X_test, y_test)

# Membuat model AdaBoost
adaboost_model = AdaBoostClassifier()
print("\nAdaBoostClassifier:")
train_model(adaboost_model, X_train, y_train, X_test, y_test)
# Out:
# Gradient Boosting Classifier:
# Accuracy on training set: 0.838
# Accuracy on test set: 0.818
#
# Decision Tree Classifier:
# Accuracy on training set: 1.000
# Accuracy on test set: 0.761
#
# Random Forest Classifier:
# Accuracy on training set: 1.000
# Accuracy on test set: 0.802
#
# Support Vector Machine Classifier:
# Accuracy on training set: 0.745
# Accuracy on test set: 0.737
#
# KNeighbors Classifier:
# Accuracy on training set: 0.815
# Accuracy on test set: 0.710
#
# Logistic Regression Classifier:
# C:\Users\Lenovo\scoop\apps\python311\current\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# Memisahkan fitur dan label
X = df_clean_umur_train.drop(columns=['sehat', 'id'])  # Menghilangkan kolom 'sehat' dan 'id' dari fitur
y = df_clean_umur_train['sehat']  # Menggunakan 'sehat' sebagai label

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode labels (y)
y_encoded = label_encoder.fit_transform(y)

# Melakukan one-hot encoding pada fitur-fitur kategorikal
X_encoded = pd.get_dummies(X)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Membagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)

# Inisialisasi model ANN
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Kompilasi model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Melatih model
history = model.fit(X_train, y_train, epochs=10, batch_size=64, validation_split=0.2)

# Evaluasi model pada data uji
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/10
# C:\Users\Lenovo\scoop\apps\python311\current\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6359 - loss: 0.6506 - val_accuracy: 0.7303 - val_loss: 0.5451
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7073 - loss: 0.5622 - val_accuracy: 0.7408 - val_loss: 0.5281
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7294 - loss: 0.5402 - val_accuracy: 0.7452 - val_loss: 0.5231
# Epoch 4/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7457 - loss: 0.5212 - val_accuracy: 0.7488 - val_loss: 0.5199
# Epoch 5/10
# ...

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# Memisahkan fitur dan label
X = df_clean_umur_train.drop(columns=['sehat', 'id'])  # Menghilangkan kolom 'sehat' dan 'id' dari fitur
y = df_clean_umur_train['sehat']  # Menggunakan 'sehat' sebagai label

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode labels (y)
y_encoded = label_encoder.fit_transform(y)

# Melakukan one-hot encoding pada fitur-fitur kategorikal
X_encoded = pd.get_dummies(X)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Membagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Inisialisasi model Naive Bayes
naive_bayes = GaussianNB()

# Melatih model
naive_bayes.fit(X_train, y_train)

# Memprediksi pada data uji
y_pred = naive_bayes.predict(X_test)

# Menghitung akurasi
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.463302752293578

# %% [markdown]
# # PREDIKSI CSV

# %%
# df_test_encoded = pd.get_dummies(df_test.drop(columns=['fit_body', 'id']))  # Lakukan one-hot encoding jika diperlukan
# train_pred_df = gradient_boosting.predict(df_test_encoded)

# %%
# df_test["fit_body"] = train_pred_df
# df_subset = df_test[['id', 'fit_body']]
# df_subset.to_csv("hasilml.csv", index=False
